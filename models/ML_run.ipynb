# %%
import os
import joblib
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFECV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, BayesianRidge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_decomposition import PLSRegression
from sklearn.neural_network import MLPRegressor
from catboost import CatBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import PassiveAggressiveRegressor, TheilSenRegressor, HuberRegressor, RANSACRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
from optuna.visualization import plot_optimization_history, plot_param_importances
import warnings
from sklearn.metrics import make_scorer
warnings.filterwarnings('ignore')

# %%
# --- 设置工作目录 ---
try:
    script_path = os.path.abspath(__file__)
    script_dir = os.path.dirname(script_path)
    os.chdir(script_dir)
    print("当前工作路径已设置为：", os.getcwd())
except NameError:
    print("Running interactively or __file__ not defined. Assuming current directory is correct.")
    print("当前工作路径：", os.getcwd())
# Out:
# Running interactively or __file__ not defined. Assuming current directory is correct.
# 当前工作路径： e:\git\phenomics\barley\project\uav\models

# %%
# 1. 数据加载与预处理
def load_and_preprocess_data(filepath):
    """加载数据并进行预处理"""
    data = pd.read_csv(filepath)
    
    # 处理缺失值
    if data.isnull().any().any():
        print("发现缺失值，使用中位数填补...")
        data = data.fillna(data.median(numeric_only=True))
    
    # 分离特征和目标
    X = data.iloc[:, :-1]
    y = data.iloc[:, -1]
    
    # 分类变量编码
    categorical_cols = X.select_dtypes(include=['object', 'category']).columns
    if len(categorical_cols) > 0:
        X = pd.get_dummies(X, columns=categorical_cols)
    
    return X, y

# %%
def adjusted_r2_score(y_true, y_pred, n_features, n_samples):
    r2 = r2_score(y_true, y_pred)
    return 1 - (1 - r2) * (n_samples - 1) / (n_samples - n_features - 1)

# Define the scorer for scikit-learn
def adjusted_r2_scorer(estimator, X, y):
    y_pred = estimator.predict(X)
    return adjusted_r2_score(y, y_pred, X.shape[1], len(y))

# %%
def load_and_split_data(filepath, sheet_name, target_col, random_state, condition_col='Condition', genotype_col='Genotype'):
    """
    加载数据并进行分层分组划分
    """
    # 加载数据
    data = pd.read_excel(filepath,sheet_name=sheet_name)
    if data.isnull().any().any():
        print("发现缺失值，使用中位数填补...")
        data = data.fillna(data.median(numeric_only=True))
    check_replicate(data)
    data = data[[col for col in data.columns if col.endswith(('_1', '_2', '_3', '_4', target_col, condition_col, genotype_col))]]
    # 划分数据集
    train_data, test_data = stratified_group_split(
        data,
        condition_col=condition_col,
        genotype_col=genotype_col,
        test_size=0.3,
        random_state=random_state)
    
    # 分离特征和目标
    X_train = train_data.drop(columns=[target_col,condition_col,genotype_col])
    y_train = train_data[target_col]
    X_test = test_data.drop(columns=[target_col,condition_col,genotype_col])
    y_test = test_data[target_col]
    
    return X_train, X_test, y_train, y_test

def check_replicate(data):
    # if 'Condition' not in data.columns or 'Genotype' not in data.columns:
    #     print("错误：Condition 或 Genotype 列不存在！")
    # exit()

    # 按 Condition 和 Genotype 分组，统计每组的重复次数
    replicate_counts = data.groupby(['Condition', 'Genotype']).size().reset_index(name='Replicate_Count')

    # 按 Condition 汇总，统计重复次数分布
    condition_summary = replicate_counts.groupby('Condition')['Replicate_Count'].value_counts().unstack(fill_value=0)

    # # 打印重复次数统计
    # print("\n每种 Condition 下 Genotype 的重复次数统计：")
    # print(condition_summary)

    # # 打印详细信息
    # conditions = data['Condition'].unique()
    # for condition in conditions:
    #     print(f"\nCondition: {condition}")
    #     condition_data = replicate_counts[replicate_counts['Condition'] == condition]
    #     print(f"  总 Genotype 数: {len(condition_data)}")
    #     print(f"  重复次数分布:\n{condition_data['Replicate_Count'].value_counts().sort_index()}")
        
    #     # 列出非 2 次重复的 Genotype
    #     non_standard = condition_data[condition_data['Replicate_Count'] != 2]
    #     if not non_standard.empty:
    #         print(f" 非 2 次重复的 Genotype:")
    #         for _, row in non_standard.iterrows():
    #             print(f"    Genotype {row['Genotype']}: {row['Replicate_Count']} 次")

# %%
# Feature selection function
def feature_selection(X, y):
    """使用递归特征消除进行特征选择"""
    print("\n=== 开始特征选择 ===")
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
    
    # 使用随机森林作为基础模型
    estimator = GradientBoostingRegressor(n_estimators=100, random_state=42)
    
    # 设置每次迭代删除1%的特征
    step = max(1, int(X_scaled.shape[1] * 0.01))
    
    selector = RFECV(
        estimator=estimator,
        step=step,
        cv=5,
        scoring="r2",  # Use the correctly defined scorer
        min_features_to_select=10,
        n_jobs=-1
    )
    
    try:
        selector.fit(X_scaled, y)
    except Exception as e:
        print(f"特征选择失败: {str(e)}")
        return X.columns  # Fallback to all features if selection fails
    
    # 获取选择的特征
    selected_features = X_scaled.columns[selector.support_]
    print(f"原始特征数: {X_scaled.shape[1]}, 选择后特征数: {len(selected_features)}")
    print("重要特征:", selected_features.tolist())
    
    # # 绘制特征选择结果
    # plt.figure(figsize=(10, 6))
    # n_scores = len(selector.cv_results_['mean_test_score'])
    # plt.plot(range(selector.min_features_to_select, selector.min_features_to_select + n_scores), 
    #          selector.cv_results_['mean_test_score'])
    # plt.xlabel("Number of Features Selected")
    # plt.ylabel("Cross Validation Score (Adjusted R²)")
    # plt.title("Feature Selection Performance")
    # plt.savefig('feature_selection.png')
    # plt.close()
    
    return selected_features

# %%
def train_and_optimize(X_train, y_train, X_test, y_test):
    """训练和优化回归模型"""

    # 初始化标准化器
    scaler = StandardScaler()
    
    # 对训练集和测试集进行标准化
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # 定义要测试的模型
    models = {
        'Linear Regression': LinearRegression(),
        'Ridge': Ridge(),
        'Lasso': Lasso(),
        'Random Forest': RandomForestRegressor(random_state=42),
        'XGBoost': XGBRegressor(random_state=42),
        'LightGBM': LGBMRegressor(random_state=42),
        'SVR': SVR(),
        'AdaBoost': AdaBoostRegressor(random_state=42),
        'Bayesian Ridge': BayesianRidge(),
        'KNN Regression': KNeighborsRegressor(),
        'PLSR': PLSRegression(),
        'MLP': MLPRegressor(random_state=42),
        'ElasticNet': ElasticNet(),
        'CatBoost': CatBoostRegressor(random_state=42),
        'Decision Tree': DecisionTreeRegressor(random_state=42),
        'Gradient Boosting': GradientBoostingRegressor(random_state=42),
        'RANSAC': RANSACRegressor(random_state=42)
    }
    
    # 存储结果
    results = {}
    
    for name, model in models.items():
        print(f"\n=== 训练 {name} ===")
        
        try:
            # 交叉验证
            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
            cv_mean = np.mean(cv_scores)
            cv_std = np.std(cv_scores)
            print(f"交叉验证 R²: {cv_mean:.4f} (±{cv_std:.4f})")
            
            # 训练模型
            model.fit(X_train, y_train)
            
            # 评估
            y_pred = model.predict(X_test)


            # 计算测试集 R²
            test_r2 = r2_score(y_test, y_pred)
            
            # 计算 Adjusted R²
            n = X_test.shape[0]  # 测试集样本数
            p = X_test.shape[1]  # 特征数
            adjusted_r2 = 1 - (1 - test_r2) * (n - 1) / (n - p - 1)  # Adjusted R² 公式

            results[name] = {
                                'CV_R2_mean': cv_mean,  # Now represents adjusted R²
                                'CV_R2_std': cv_std,
                                'Test_R2': test_r2,
                                'Test_Adjusted_R2': adjusted_r2,  # 添加 Adjusted R²
                                'Test_MSE': mean_squared_error(y_test, y_pred),
                                'Test_MAE': mean_absolute_error(y_test, y_pred),
                                'Model': model
                            }
            print(f"测试集 Adjusted R²: {results[name]['Test_R2']:.4f}")
            
            
        except Exception as e:
            print(f"训练 {name} 时出错: {str(e)}")
            results[name] = {
                'CV_R2_mean': None,
                'CV_R2_std': None,
                'Test_R2': None,
                'Test_MSE': None,
                'Test_MAE': None,
                'Model': None,
                'Error': str(e)
            }
    
    return results

# 4. Optuna超参数优化
def optimize_with_optuna(X_train, y_train, model_name, n_trials=100):
    
    """使用Optuna进行超参数优化"""

    # 初始化标准化器
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    
    def objective(trial):
        if model_name == 'Random Forest':
            params = {
                'n_estimators': trial.suggest_int('n_estimators', 5, 200),
                'max_depth': trial.suggest_int('max_depth', 1, 20),
                'min_samples_split': trial.suggest_int('min_samples_split', 2, 50),
                'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 50),
                'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None])}
            model = RandomForestRegressor(**params, random_state=42)
            
        elif model_name == 'XGBoost':
            params = {
                'n_estimators': trial.suggest_int('n_estimators', 5, 1000),
                'max_depth': trial.suggest_int('max_depth', 3, 20),
                'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.3, log=True),
                'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0)
            }
            model = XGBRegressor(**params, random_state=42)
            
        elif model_name == 'LightGBM':
            params = {
                'n_estimators': trial.suggest_int('n_estimators', 5, 1000),
                'max_depth': trial.suggest_int('max_depth', 3, 20),
                'learning_rate': trial.suggest_float('learning_rate', 1e-3, 0.3, log=True),
                'num_leaves': trial.suggest_int('num_leaves', 10, 200),
                'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0)
            }
            model = LGBMRegressor(**params, random_state=42)

        elif model_name == 'SVR':
            params = {
                'C': trial.suggest_float('C', 1e-2, 1e2, log=True),
                'epsilon': trial.suggest_float('epsilon', 1e-3, 1.0, log=True),
                'kernel': trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly'])
            }
            model = SVR(**params)
        
        elif model_name == 'Ridge':
            params = {
                'alpha': trial.suggest_float('alpha', 1e-2, 1e2, log=True),
                'solver': trial.suggest_categorical('solver', ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'])
            }
            model = Ridge(**params)

        elif model_name == 'KNN Regression':
            params = {
                'n_neighbors': trial.suggest_int('n_neighbors', 1, 30),  # 邻近点数量
                'weights': trial.suggest_categorical('weights', ['uniform', 'distance']),  # 权重类型
                'algorithm': trial.suggest_categorical('algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute'])  # 算法类型
            }
            model = KNeighborsRegressor(**params)

        elif model_name == 'CatBoost':
            params = {
                'iterations': trial.suggest_int('iterations', 100, 1000),  # 迭代次数
                'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),  # 学习率
                'depth': trial.suggest_int('depth', 4, 10),  # 树的深度
                'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10),  # 叶子节点的 L2 正则化系数
                'border_count': trial.suggest_int('border_count', 32, 255),  # 分割特征时考虑的边界数量
                'thread_count': trial.suggest_int('thread_count', 1, 8),  # 线程数
                'random_seed': trial.suggest_int('random_seed', 1, 1000)  # 随机种子
            }
            model = CatBoostRegressor(**params, random_state=42)
        

        score = cross_val_score(model, X_train, y_train, cv=5, scoring=adjusted_r2_scorer, n_jobs=-1).mean()
        return score
    
    study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)
    
    print(f"\n最佳 {model_name} 参数:")
    for key, value in study.best_params.items():
        print(f"{key}: {value}")
    
    # # 可视化优化过程
    # fig = plot_optimization_history(study)
    # fig.write_image(f"{model_name.lower().replace(' ', '_')}_optimization_history.png")
    
    # fig = plot_param_importances(study)
    # fig.write_image(f"{model_name.lower().replace(' ', '_')}_param_importance.png")
    
    return study.best_params

def stratified_group_split(data, condition_col, genotype_col, test_size=0.2, random_state=42):
    """
    根据Condition列进行分层划分，并确保同一个Genotype不出现在训练集和测试集中。
    
    参数:
        data: pandas DataFrame，包含数据集
        condition_col: str，Condition列名
        genotype_col: str，Genotype列名
        test_size: float，测试集比例
        random_state: int，随机种子
    
    返回:
        train_data: 训练集DataFrame
        test_data: 测试集DataFrame
    """
    # 确保输入数据包含必要的列
    if condition_col not in data.columns or genotype_col not in data.columns:
        raise ValueError("Condition或Genotype列不存在！")
    
    # 按Genotype分组，获取每组的Condition值（假设每组的Condition一致）
    grouped = data.groupby(genotype_col)[condition_col].first().reset_index()
    
    # 对Genotype进行分层划分，基于Condition
    train_groups, test_groups = train_test_split(
        grouped,
        test_size=test_size,
        stratify=grouped[condition_col],
        random_state=random_state
    )
    
    # 根据划分的Genotype组，提取完整的训练集和测试集
    train_data = data[data[genotype_col].isin(train_groups[genotype_col])]
    test_data = data[data[genotype_col].isin(test_groups[genotype_col])]
    
    # 验证Condition分布
    train_condition_dist = train_data[condition_col].value_counts(normalize=True)
    test_condition_dist = test_data[condition_col].value_counts(normalize=True)
    # print("\n训练集Condition分布：")
    # print(train_condition_dist)
    # print("\n测试集Condition分布：")
    # print(test_condition_dist)
    
    # 验证Genotype不重复
    train_genotypes = set(train_data[genotype_col])
    test_genotypes = set(test_data[genotype_col])
    overlapping_genotypes = train_genotypes.intersection(test_genotypes)
    if overlapping_genotypes:
        raise ValueError(f"发现Genotype重复：{overlapping_genotypes}")
    else:
        print("\n验证通过：训练集和测试集的Genotype无重复")
    
    # # 可视化Condition分布
    # plt.figure(figsize=(8, 5))
    # plt.subplot(1, 2, 1)
    # train_condition_dist.plot(kind='bar', title='Train Condition Distribution')
    # plt.subplot(1, 2, 2)
    # test_condition_dist.plot(kind='bar', title='Test Condition Distribution')
    # plt.tight_layout()
    # plt.savefig('condition_distribution.png')
    # plt.close()
    
    return train_data, test_data

# %%
data_path = 'file2.xlsx'
sheet_name = "2d_TKW"
target_col = "1000GrainWeight"
X_train, X_test, y_train, y_test = load_and_split_data(data_path, sheet_name=sheet_name, target_col=target_col, random_state=42)
# print(X_train)

# # Feature Selection
selected_features = feature_selection(X_train, y_train)
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# 基础模型训练
print("\n=== 基础模型比较 ===")
scaler = StandardScaler()
X_train_selected = scaler.fit_transform(X_train_selected)
X_test_selected = scaler.transform(X_test_selected)
results = train_and_optimize(X_train_selected, y_train, X_test_selected, y_test)

# 保存结果
results_df = pd.DataFrame(results).T
results_df.drop(columns=['Model'], inplace=True)
results_df.rename(columns={'Test_R2': 'Test_Adjusted_R2', 'CV_R2_mean': 'CV_Adjusted_R2_mean'}, inplace=True)
results_file = f"model_performance_{sheet_name}.csv"
results_df.to_csv(results_file)
print("\n模型结果已保存到 model_performance")

# results_df['random_state'] = dataset_random_state
# all_results.append(results_df)

# # 选择最佳模型进行优化
# best_model_name = max(results, key=lambda x: results[x]['Test_R2'])
# print(f"\n选择最佳模型进行优化: {best_model_name}")

# # 超参数优化
# best_params = optimize_with_optuna(X_train_selected, y_train, best_model_name)

# # 用最优参数训练最终模型
# if best_model_name == 'Random Forest':
#     final_model = RandomForestRegressor(**best_params, random_state=42)
# elif best_model_name == 'XGBoost':
#     final_model = XGBRegressor(**best_params, random_state=42)
# elif best_model_name == 'LightGBM':
#     final_model = LGBMRegressor(**best_params, random_state=42)
# elif best_model_name == 'Ridge':
#     final_model = Ridge(**best_params)
# elif best_model_name == 'KNN Regression':
#     final_model = KNeighborsRegressor(**best_params)
# elif best_model_name == 'CatBoost':
#     final_model = CatBoostRegressor(**best_params,random_state=42)
# final_model.fit(X_train_selected, y_train)

# # 评估最终模型
# y_pred = final_model.predict(X_test_selected)
# final_r2 = adjusted_r2_score(y_test, y_pred, X_test_selected.shape[1], len(y_test))
# print(f"\n优化后模型 R²: {final_r2:.4f}")

# if hasattr(final_model, 'feature_importances_'):
#     plt.figure(figsize=(10, 6))
#     feat_importances = pd.Series(final_model.feature_importances_, index=selected_features)
#     feat_importances.nlargest(10).plot(kind='barh')
#     plt.title("Top 10 Important Features")
#     plt.savefig('feature_importance.png')
#     plt.close()
# else:
#     print(f"{best_model_name} 不支持特征重要性可视化")
# final_results = pd.concat(all_results)
# final_results.groupby('Model').agg({'Test_R2': ['mean', 'std']}).to_csv('model_stability.csv')
# Out:
# 验证通过：训练集和测试集的Genotype无重复
#
# === 开始特征选择 ===
# 原始特征数: 37, 选择后特征数: 28
# 重要特征: ['CIgreen_mean_msi_1', 'CIgreen_mean_msi_2', 'CIgreen_mean_msi_3', 'CIgreen_mean_msi_4', 'EVI_mean_msi_1', 'ExG_mean_rgb_3', 'GARI_mean_msi_4', 'IKAW_mean_rgb_1', 'IKAW_mean_rgb_2', 'NDREI_mean_msi_4', 'PSRI_mean_msi_1', 'PSRI_mean_msi_2', 'PSRI_mean_msi_3', 'PSRI_mean_msi_4', 'S-CCCI_mean_msi_2', 'S-CCCI_mean_msi_3', 'TCARI_mean_msi_2', 'TCARI_mean_msi_3', 'TCARI_mean_msi_4', 'VARI_mean_msi_1', 'VARI_mean_msi_2', 'VARI_mean_msi_3', 'VARI_mean_msi_4', 'VARI_mean_rgb_4', 'VNDVI_mean_rgb_2', 'VNDVI_mean_rgb_3', 'VNDVI_mean_rgb_4', 'Vopt1_mean_msi_4']
#
# === 基础模型比较 ===
#
# === 训练 Linear Regression ===
# 交叉验证 R²: -0.9641 (±1.5433)
# 测试集 Adjusted R²: 0.2364
#
# === 训练 Ridge ===
# 交叉验证 R²: -0.9721 (±1.5774)
# 测试集 Adjusted R²: 0.2716
#
# === 训练 Lasso ===
# 交叉验证 R²: -0.6813 (±1.1499)
# 测试集 Adjusted R²: 0.3155
#
# === 训练 Random Forest ===
# 交叉验证 R²: -0.2102 (±0.5791)
# 测试集 Adjusted R²: 0.3023
#
# === 训练 XGBoost ===
# 交叉验证 R²: -0.3563 (±0.5970)
# 测试集 Adjusted R²: 0.0852
#
# === 训练 LightGBM ===
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033914 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1540
# [LightGBM] [Info] Number of data points in the train set: 160, number of used features: 28
# [LightGBM] [Info] Start training from score 35.657564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031850 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1540
# [LightGBM] [Info] Number of data points in the train set: 160, number of used features: 28
# [LightGBM] [Info] Start training from score 37.087048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000313 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1540
# [LightGBM] [Info] Number of data points in the train set: 160, number of used features: 28
# [LightGBM] [Info] Start training from score 37.217281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1540
# [LightGBM] [Info] Number of data points in the train set: 160, number of used features: 28
# [LightGBM] [Info] Start training from score 38.004511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1540
# [LightGBM] [Info] Number of data points in the train set: 160, number of used features: 28
# [LightGBM] [Info] Start training from score 37.865694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 交叉验证 R²: -0.3459 (±0.6423)
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000449 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1909
# [LightGBM] [Info] Number of data points in the train set: 200, number of used features: 28
# [LightGBM] [Info] Start training from score 37.166420
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 698:	learn: 0.3556515	total: 2.86s	remaining: 1.23s
# 699:	learn: 0.3532933	total: 2.86s	remaining: 1.23s
# 700:	learn: 0.3512003	total: 2.87s	remaining: 1.22s
# 701:	learn: 0.3493112	total: 2.87s	remaining: 1.22s
# 702:	learn: 0.3485875	total: 2.87s	remaining: 1.21s
# 703:	learn: 0.3470411	total: 2.88s	remaining: 1.21s
# 704:	learn: 0.3466805	total: 2.88s	remaining: 1.21s
# 705:	learn: 0.3453412	total: 2.88s	remaining: 1.2s
# 706:	learn: 0.3441213	total: 2.89s	remaining: 1.2s
# 707:	learn: 0.3425791	total: 2.89s	remaining: 1.19s
# 708:	learn: 0.3413490	total: 2.9s	remaining: 1.19s
# 709:	learn: 0.3410091	total: 2.9s	remaining: 1.18s
# 710:	learn: 0.3392213	total: 2.9s	remaining: 1.18s
# 711:	learn: 0.3370247	total: 2.91s	remaining: 1.18s
# 712:	learn: 0.3356752	total: 2.91s	remaining: 1.17s
# 713:	learn: 0.3353484	total: 2.92s	remaining: 1.17s
# 714:	learn: 0.3343572	total: 2.92s	remaining: 1.16s
# 715:	learn: 0.3327866	total: 2.93s	remaining: 1.16s
# 716:	learn: 0.3316427	total: 2.93s	remaining: 1.16s
# 717:	learn: 0.3294644	total: 2.94s	remaining: 1.15s
# 718:	learn: 0.3277563	total: 2.94s	remaining: 1.15s
# 719:	learn: 0.3268712	total: 2.94s	remaining: 1.14s
# 720:	learn: 0.3247761	total: 2.95s	remaining: 1.14s
# 721:	learn: 0.3238970	total: 2.95s	remaining: 1.14s
# 722:	learn: 0.3223904	total: 2.95s	remaining: 1.13s
# 723:	learn: 0.3204036	total: 2.96s	remaining: 1.13s
# 724:	learn: 0.3196661	total: 2.96s	remaining: 1.12s
# 725:	learn: 0.3177873	total: 2.96s	remaining: 1.12s
# 726:	learn: 0.3160463	total: 2.97s	remaining: 1.11s
# 727:	learn: 0.3143951	total: 2.97s	remaining: 1.11s
# 728:	learn: 0.3130132	total: 2.98s	remaining: 1.11s
# 729:	learn: 0.3116333	total: 2.98s	remaining: 1.1s
# 730:	learn: 0.3101262	total: 2.98s	remaining: 1.1s
# 731:	learn: 0.3092875	total: 2.99s	remaining: 1.09s
# 732:	learn: 0.3091259	total: 2.99s	remaining: 1.09s
# 733:	learn: 0.3084093	total: 2.99s	remaining: 1.08s
# 734:	learn: 0.3067924	total: 3s	remaining: 1.08s
# 735:	learn: 0.3065807	total: 3s	remaining: 1.08s
# 736:	learn: 0.3064170	total: 3.01s	remaining: 1.07s
# 737:	learn: 0.3050711	total: 3.01s	remaining: 1.07s
# 738:	learn: 0.3046309	total: 3.01s	remaining: 1.06s
# 739:	learn: 0.3029151	total: 3.02s	remaining: 1.06s
# 740:	learn: 0.3026208	total: 3.02s	remaining: 1.05s
# 741:	learn: 0.3014242	total: 3.02s	remaining: 1.05s
# 742:	learn: 0.3000446	total: 3.03s	remaining: 1.05s
# 743:	learn: 0.2988192	total: 3.03s	remaining: 1.04s
# 744:	learn: 0.2985616	total: 3.03s	remaining: 1.04s
# 745:	learn: 0.2975866	total: 3.04s	remaining: 1.03s
# 746:	learn: 0.2957233	total: 3.04s	remaining: 1.03s
# 747:	learn: 0.2939593	total: 3.04s	remaining: 1.02s
# 748:	learn: 0.2923645	total: 3.05s	remaining: 1.02s
# 749:	learn: 0.2922306	total: 3.05s	remaining: 1.02s
# 750:	learn: 0.2920143	total: 3.05s	remaining: 1.01s
# 751:	learn: 0.2915300	total: 3.06s	remaining: 1.01s
# 752:	learn: 0.2901951	total: 3.06s	remaining: 1s
# 753:	learn: 0.2898314	total: 3.06s	remaining: 1s
# 754:	learn: 0.2882355	total: 3.07s	remaining: 996ms
# 755:	learn: 0.2879805	total: 3.07s	remaining: 992ms
# 756:	learn: 0.2875978	total: 3.08s	remaining: 988ms
# 757:	learn: 0.2869617	total: 3.08s	remaining: 983ms
# 758:	learn: 0.2863681	total: 3.08s	remaining: 979ms
# 759:	learn: 0.2851882	total: 3.09s	remaining: 975ms
# 760:	learn: 0.2846376	total: 3.09s	remaining: 971ms
# 761:	learn: 0.2834831	total: 3.1s	remaining: 967ms
# 762:	learn: 0.2826731	total: 3.1s	remaining: 963ms
# 763:	learn: 0.2812870	total: 3.1s	remaining: 959ms
# 764:	learn: 0.2803951	total: 3.11s	remaining: 954ms
# 765:	learn: 0.2793087	total: 3.11s	remaining: 950ms
# 766:	learn: 0.2788076	total: 3.11s	remaining: 946ms
# 767:	learn: 0.2779723	total: 3.12s	remaining: 942ms
# 768:	learn: 0.2766196	total: 3.12s	remaining: 938ms
# 769:	learn: 0.2762239	total: 3.13s	remaining: 934ms
# 770:	learn: 0.2749030	total: 3.13s	remaining: 929ms
# 771:	learn: 0.2734691	total: 3.13s	remaining: 925ms
# 772:	learn: 0.2721804	total: 3.14s	remaining: 921ms
# 773:	learn: 0.2719898	total: 3.14s	remaining: 917ms
# 774:	learn: 0.2705318	total: 3.14s	remaining: 913ms
# 775:	learn: 0.2691349	total: 3.15s	remaining: 909ms
# 776:	learn: 0.2676513	total: 3.15s	remaining: 904ms
# 777:	learn: 0.2666334	total: 3.15s	remaining: 900ms
# 778:	learn: 0.2651214	total: 3.16s	remaining: 896ms
# 779:	learn: 0.2634509	total: 3.16s	remaining: 892ms
# 780:	learn: 0.2627684	total: 3.17s	remaining: 888ms
# 781:	learn: 0.2626212	total: 3.17s	remaining: 883ms
# 782:	learn: 0.2614617	total: 3.17s	remaining: 879ms
# 783:	learn: 0.2610835	total: 3.18s	remaining: 875ms
# 784:	learn: 0.2604209	total: 3.18s	remaining: 871ms
# 785:	learn: 0.2602346	total: 3.18s	remaining: 867ms
# 786:	learn: 0.2584493	total: 3.19s	remaining: 862ms
# 787:	learn: 0.2572371	total: 3.19s	remaining: 858ms
# 788:	learn: 0.2571095	total: 3.19s	remaining: 854ms
# 789:	learn: 0.2560672	total: 3.2s	remaining: 850ms
# 790:	learn: 0.2545113	total: 3.2s	remaining: 846ms
# 791:	learn: 0.2533324	total: 3.2s	remaining: 842ms
# 792:	learn: 0.2519984	total: 3.21s	remaining: 837ms
# 793:	learn: 0.2516245	total: 3.21s	remaining: 833ms
# 794:	learn: 0.2504738	total: 3.21s	remaining: 829ms
# 795:	learn: 0.2488520	total: 3.22s	remaining: 825ms
# 796:	learn: 0.2480245	total: 3.22s	remaining: 821ms
# 797:	learn: 0.2465982	total: 3.23s	remaining: 816ms
# 798:	learn: 0.2458995	total: 3.23s	remaining: 812ms
# 799:	learn: 0.2457065	total: 3.23s	remaining: 808ms
# 800:	learn: 0.2445573	total: 3.24s	remaining: 804ms
# 801:	learn: 0.2436314	total: 3.24s	remaining: 800ms
# 802:	learn: 0.2422752	total: 3.24s	remaining: 796ms
# 803:	learn: 0.2409739	total: 3.25s	remaining: 792ms
# 804:	learn: 0.2396322	total: 3.25s	remaining: 787ms
# 805:	learn: 0.2387365	total: 3.25s	remaining: 783ms
# 806:	learn: 0.2375466	total: 3.26s	remaining: 779ms
# 807:	learn: 0.2365504	total: 3.26s	remaining: 775ms
# 808:	learn: 0.2362906	total: 3.26s	remaining: 771ms
# 809:	learn: 0.2360369	total: 3.27s	remaining: 766ms
# 810:	learn: 0.2348542	total: 3.27s	remaining: 762ms
# 811:	learn: 0.2343350	total: 3.27s	remaining: 758ms
# 812:	learn: 0.2341392	total: 3.28s	remaining: 754ms
# 813:	learn: 0.2332348	total: 3.28s	remaining: 750ms
# 814:	learn: 0.2324550	total: 3.29s	remaining: 746ms
# 815:	learn: 0.2314934	total: 3.29s	remaining: 742ms
# 816:	learn: 0.2313301	total: 3.29s	remaining: 738ms
# 817:	learn: 0.2306137	total: 3.3s	remaining: 734ms
# 818:	learn: 0.2294177	total: 3.3s	remaining: 730ms
# 819:	learn: 0.2290705	total: 3.31s	remaining: 726ms
# 820:	learn: 0.2278237	total: 3.31s	remaining: 722ms
# 821:	learn: 0.2270997	total: 3.31s	remaining: 717ms
# 822:	learn: 0.2269252	total: 3.32s	remaining: 713ms
# 823:	learn: 0.2267460	total: 3.32s	remaining: 709ms
# 824:	learn: 0.2261476	total: 3.32s	remaining: 705ms
# 825:	learn: 0.2250837	total: 3.33s	remaining: 701ms
# 826:	learn: 0.2239282	total: 3.33s	remaining: 697ms
# 827:	learn: 0.2234407	total: 3.33s	remaining: 693ms
# 828:	learn: 0.2220122	total: 3.34s	remaining: 689ms
# 829:	learn: 0.2218938	total: 3.34s	remaining: 684ms
# 830:	learn: 0.2214150	total: 3.34s	remaining: 680ms
# 831:	learn: 0.2212340	total: 3.35s	remaining: 676ms
# 832:	learn: 0.2200634	total: 3.35s	remaining: 672ms
# 833:	learn: 0.2193916	total: 3.36s	remaining: 668ms
# 834:	learn: 0.2183157	total: 3.36s	remaining: 664ms
# 835:	learn: 0.2179941	total: 3.36s	remaining: 660ms
# 836:	learn: 0.2174970	total: 3.37s	remaining: 656ms
# 837:	learn: 0.2166149	total: 3.37s	remaining: 651ms
# 838:	learn: 0.2156007	total: 3.37s	remaining: 647ms
# 839:	learn: 0.2149905	total: 3.38s	remaining: 643ms
# 840:	learn: 0.2136686	total: 3.38s	remaining: 639ms
# 841:	learn: 0.2124875	total: 3.38s	remaining: 635ms
# 842:	learn: 0.2122356	total: 3.39s	remaining: 631ms
# 843:	learn: 0.2120639	total: 3.39s	remaining: 627ms
# 844:	learn: 0.2111031	total: 3.39s	remaining: 623ms
# 845:	learn: 0.2102379	total: 3.4s	remaining: 619ms
# 846:	learn: 0.2094495	total: 3.4s	remaining: 614ms
# 847:	learn: 0.2083947	total: 3.4s	remaining: 610ms
# 848:	learn: 0.2071539	total: 3.41s	remaining: 606ms
# 849:	learn: 0.2058514	total: 3.41s	remaining: 602ms
# 850:	learn: 0.2050117	total: 3.41s	remaining: 598ms
# 851:	learn: 0.2039698	total: 3.42s	remaining: 594ms
# 852:	learn: 0.2029899	total: 3.42s	remaining: 590ms
# 853:	learn: 0.2016965	total: 3.42s	remaining: 586ms
# 854:	learn: 0.2009576	total: 3.43s	remaining: 582ms
# 855:	learn: 0.2001146	total: 3.43s	remaining: 577ms
# 856:	learn: 0.1990994	total: 3.44s	remaining: 573ms
# 857:	learn: 0.1989331	total: 3.44s	remaining: 569ms
# 858:	learn: 0.1982916	total: 3.44s	remaining: 565ms
# 859:	learn: 0.1977118	total: 3.44s	remaining: 561ms
# 860:	learn: 0.1972141	total: 3.45s	remaining: 557ms
# 861:	learn: 0.1963270	total: 3.45s	remaining: 553ms
# 862:	learn: 0.1949587	total: 3.46s	remaining: 548ms
# 863:	learn: 0.1938295	total: 3.46s	remaining: 544ms
# 864:	learn: 0.1931947	total: 3.46s	remaining: 540ms
# 865:	learn: 0.1924651	total: 3.46s	remaining: 536ms
# 866:	learn: 0.1917666	total: 3.47s	remaining: 532ms
# 867:	learn: 0.1915448	total: 3.47s	remaining: 528ms
# 868:	learn: 0.1904012	total: 3.48s	remaining: 524ms
# 869:	learn: 0.1902297	total: 3.48s	remaining: 520ms
# 870:	learn: 0.1896381	total: 3.48s	remaining: 516ms
# 871:	learn: 0.1887112	total: 3.49s	remaining: 512ms
# 872:	learn: 0.1878825	total: 3.49s	remaining: 508ms
# 873:	learn: 0.1873919	total: 3.5s	remaining: 504ms
# 874:	learn: 0.1861982	total: 3.5s	remaining: 500ms
# 875:	learn: 0.1860527	total: 3.5s	remaining: 496ms
# 876:	learn: 0.1857296	total: 3.51s	remaining: 492ms
# 877:	learn: 0.1853940	total: 3.51s	remaining: 488ms
# 878:	learn: 0.1849043	total: 3.52s	remaining: 484ms
# 879:	learn: 0.1839926	total: 3.52s	remaining: 480ms
# 880:	learn: 0.1832159	total: 3.52s	remaining: 476ms
# 881:	learn: 0.1828923	total: 3.53s	remaining: 472ms
# 882:	learn: 0.1821032	total: 3.53s	remaining: 468ms
# 883:	learn: 0.1810740	total: 3.53s	remaining: 464ms
# 884:	learn: 0.1806363	total: 3.54s	remaining: 460ms
# 885:	learn: 0.1799071	total: 3.54s	remaining: 456ms
# 886:	learn: 0.1792881	total: 3.54s	remaining: 452ms
# 887:	learn: 0.1786353	total: 3.55s	remaining: 448ms
# 888:	learn: 0.1785132	total: 3.55s	remaining: 443ms
# 889:	learn: 0.1778118	total: 3.56s	remaining: 439ms
# 890:	learn: 0.1771011	total: 3.56s	remaining: 435ms
# 891:	learn: 0.1760595	total: 3.56s	remaining: 431ms
# 892:	learn: 0.1755014	total: 3.56s	remaining: 427ms
# 893:	learn: 0.1753885	total: 3.57s	remaining: 423ms
# 894:	learn: 0.1746200	total: 3.57s	remaining: 419ms
# 895:	learn: 0.1739528	total: 3.58s	remaining: 415ms
# 896:	learn: 0.1732498	total: 3.58s	remaining: 411ms
# 897:	learn: 0.1722731	total: 3.58s	remaining: 407ms
# 898:	learn: 0.1717651	total: 3.59s	remaining: 403ms
# 899:	learn: 0.1712473	total: 3.59s	remaining: 399ms
# 900:	learn: 0.1707918	total: 3.59s	remaining: 395ms
# 901:	learn: 0.1699246	total: 3.6s	remaining: 391ms
# 902:	learn: 0.1691482	total: 3.6s	remaining: 387ms
# 903:	learn: 0.1687195	total: 3.6s	remaining: 383ms
# 904:	learn: 0.1681489	total: 3.61s	remaining: 379ms
# 905:	learn: 0.1680331	total: 3.61s	remaining: 375ms
# 906:	learn: 0.1675384	total: 3.61s	remaining: 371ms
# 907:	learn: 0.1664746	total: 3.62s	remaining: 367ms
# 908:	learn: 0.1657165	total: 3.62s	remaining: 363ms
# 909:	learn: 0.1650799	total: 3.63s	remaining: 359ms
# 910:	learn: 0.1645977	total: 3.63s	remaining: 354ms
# 911:	learn: 0.1641431	total: 3.63s	remaining: 350ms
# 912:	learn: 0.1634528	total: 3.63s	remaining: 346ms
# 913:	learn: 0.1628519	total: 3.64s	remaining: 342ms
# 914:	learn: 0.1624327	total: 3.64s	remaining: 338ms
# 915:	learn: 0.1622120	total: 3.65s	remaining: 334ms
# 916:	learn: 0.1614027	total: 3.65s	remaining: 330ms
# 917:	learn: 0.1605541	total: 3.65s	remaining: 326ms
# 918:	learn: 0.1604228	total: 3.65s	remaining: 322ms
# 919:	learn: 0.1601862	total: 3.66s	remaining: 318ms
# 920:	learn: 0.1592467	total: 3.66s	remaining: 314ms
# 921:	learn: 0.1586848	total: 3.66s	remaining: 310ms
# 922:	learn: 0.1576214	total: 3.67s	remaining: 306ms
# 923:	learn: 0.1570335	total: 3.67s	remaining: 302ms
# 924:	learn: 0.1564798	total: 3.67s	remaining: 298ms
# 925:	learn: 0.1560628	total: 3.68s	remaining: 294ms
# 926:	learn: 0.1558989	total: 3.68s	remaining: 290ms
# 927:	learn: 0.1557594	total: 3.69s	remaining: 286ms
# 928:	learn: 0.1549770	total: 3.69s	remaining: 282ms
# 929:	learn: 0.1542107	total: 3.69s	remaining: 278ms
# 930:	learn: 0.1537401	total: 3.7s	remaining: 274ms
# 931:	learn: 0.1536177	total: 3.7s	remaining: 270ms
# 932:	learn: 0.1530772	total: 3.7s	remaining: 266ms
# 933:	learn: 0.1524987	total: 3.71s	remaining: 262ms
# 934:	learn: 0.1523951	total: 3.71s	remaining: 258ms
# 935:	learn: 0.1520819	total: 3.71s	remaining: 254ms
# 936:	learn: 0.1514264	total: 3.72s	remaining: 250ms
# 937:	learn: 0.1513267	total: 3.72s	remaining: 246ms
# 938:	learn: 0.1508388	total: 3.72s	remaining: 242ms
# 939:	learn: 0.1499720	total: 3.73s	remaining: 238ms
# 940:	learn: 0.1490571	total: 3.73s	remaining: 234ms
# 941:	learn: 0.1482958	total: 3.73s	remaining: 230ms
# 942:	learn: 0.1481941	total: 3.74s	remaining: 226ms
# 943:	learn: 0.1477997	total: 3.74s	remaining: 222ms
# 944:	learn: 0.1468687	total: 3.74s	remaining: 218ms
# 945:	learn: 0.1465420	total: 3.75s	remaining: 214ms
# 946:	learn: 0.1464307	total: 3.75s	remaining: 210ms
# 947:	learn: 0.1459556	total: 3.75s	remaining: 206ms
# 948:	learn: 0.1458086	total: 3.76s	remaining: 202ms
# 949:	learn: 0.1454796	total: 3.76s	remaining: 198ms
# 950:	learn: 0.1453544	total: 3.77s	remaining: 194ms
# 951:	learn: 0.1448407	total: 3.77s	remaining: 190ms
# 952:	learn: 0.1440760	total: 3.77s	remaining: 186ms
# 953:	learn: 0.1435666	total: 3.78s	remaining: 182ms
# 954:	learn: 0.1433014	total: 3.78s	remaining: 178ms
# 955:	learn: 0.1427607	total: 3.78s	remaining: 174ms
# 956:	learn: 0.1420064	total: 3.79s	remaining: 170ms
# 957:	learn: 0.1418875	total: 3.79s	remaining: 166ms
# 958:	learn: 0.1410792	total: 3.79s	remaining: 162ms
# 959:	learn: 0.1401847	total: 3.8s	remaining: 158ms
# 960:	learn: 0.1398364	total: 3.8s	remaining: 154ms
# 961:	learn: 0.1397363	total: 3.8s	remaining: 150ms
# 962:	learn: 0.1389644	total: 3.81s	remaining: 146ms
# 963:	learn: 0.1385217	total: 3.81s	remaining: 142ms
# 964:	learn: 0.1378176	total: 3.81s	remaining: 138ms
# 965:	learn: 0.1372853	total: 3.82s	remaining: 134ms
# 966:	learn: 0.1370438	total: 3.82s	remaining: 130ms
# 967:	learn: 0.1365645	total: 3.83s	remaining: 126ms
# 968:	learn: 0.1363231	total: 3.83s	remaining: 122ms
# 969:	learn: 0.1358347	total: 3.83s	remaining: 119ms
# 970:	learn: 0.1352089	total: 3.84s	remaining: 115ms
# 971:	learn: 0.1345075	total: 3.84s	remaining: 111ms
# 972:	learn: 0.1344314	total: 3.84s	remaining: 107ms
# 973:	learn: 0.1339036	total: 3.85s	remaining: 103ms
# 974:	learn: 0.1333772	total: 3.85s	remaining: 98.7ms
# 975:	learn: 0.1330537	total: 3.85s	remaining: 94.8ms
# 976:	learn: 0.1324295	total: 3.86s	remaining: 90.8ms
# 977:	learn: 0.1317594	total: 3.86s	remaining: 86.8ms
# 978:	learn: 0.1312447	total: 3.86s	remaining: 82.9ms
# 979:	learn: 0.1308806	total: 3.87s	remaining: 78.9ms
# 980:	learn: 0.1305138	total: 3.87s	remaining: 75ms
# 981:	learn: 0.1300191	total: 3.87s	remaining: 71ms
# 982:	learn: 0.1294539	total: 3.88s	remaining: 67.1ms
# 983:	learn: 0.1292314	total: 3.88s	remaining: 63.1ms
# 984:	learn: 0.1291213	total: 3.88s	remaining: 59.2ms
# 985:	learn: 0.1285651	total: 3.89s	remaining: 55.2ms
# 986:	learn: 0.1278024	total: 3.89s	remaining: 51.3ms
# 987:	learn: 0.1275372	total: 3.9s	remaining: 47.3ms
# 988:	learn: 0.1269284	total: 3.9s	remaining: 43.4ms
# 989:	learn: 0.1261592	total: 3.9s	remaining: 39.4ms
# 990:	learn: 0.1253802	total: 3.91s	remaining: 35.5ms
# 991:	learn: 0.1247530	total: 3.91s	remaining: 31.6ms
# 992:	learn: 0.1242404	total: 3.92s	remaining: 27.6ms
# 993:	learn: 0.1235253	total: 3.93s	remaining: 23.7ms
# 994:	learn: 0.1227999	total: 3.93s	remaining: 19.8ms
# 995:	learn: 0.1223487	total: 3.93s	remaining: 15.8ms
# 996:	learn: 0.1219033	total: 3.94s	remaining: 11.8ms
# 997:	learn: 0.1212136	total: 3.94s	remaining: 7.9ms
# 998:	learn: 0.1208257	total: 3.94s	remaining: 3.95ms
# 999:	learn: 0.1202450	total: 3.95s	remaining: 0us
# 测试集 Adjusted R²: 0.3145
#
# === 训练 Decision Tree ===
# 交叉验证 R²: -0.8517 (±0.3618)
# 测试集 Adjusted R²: -0.1650
#
# === 训练 Gradient Boosting ===
# 交叉验证 R²: -0.2225 (±0.4636)
# 测试集 Adjusted R²: 0.3384
#
# === 训练 RANSAC ===
# 交叉验证 R²: -3.1214 (±2.1927)
# 测试集 Adjusted R²: -2.0159
#
# 模型结果已保存到 model_performance
